# %%
import pandas as pd
import import_ipynb
from Preprocessing import *
# Out:
# importing Jupyter notebook from Preprocessing.ipynb

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#                     id                                         tweet_text  \
# 0  1031761728445530112                          @Tixaa23 14 para eu ir :)
# 1  1031761040462278656      @drexalvarez O meu like eu já dei na época :)
# 2  1031760962372689920  Eu só queria conseguir comer alguma coisa pra ...
# 3  1031760948250456066                                 :D que lindo dia !
# 4  1031760895985246208  @Primo_Resmungao Pq da pr jeito!!é uma "oferta...
#
#                        tweet_date sentiment query_used
# 0  Tue Aug 21 04:35:39 +0000 2018  Positivo         :)
# 1  Tue Aug 21 04:32:55 +0000 2018  Positivo         :)
# 2  Tue Aug 21 04:32:37 +0000 2018  Positivo         :)
# 3  Tue Aug 21 04:32:33 +0000 2018  Positivo         :)
# 4  Tue Aug 21 04:32:21 +0000 2018  Positivo         :)

# %%
data.shape
# Out:
# (785814, 5)

# %%
data = data.drop(columns=['id', 'tweet_date', 'query_used'])
data = data.rename({'tweet_text': 'text', 'sentiment': 'target'}, axis=1)
data['target'] = data['target'].apply(lowercase)
data.head()
# Out:
#                                                 text    target
# 0                          @Tixaa23 14 para eu ir :)  positivo
# 1      @drexalvarez O meu like eu já dei na época :)  positivo
# 2  Eu só queria conseguir comer alguma coisa pra ...  positivo
# 3                                 :D que lindo dia !  positivo
# 4  @Primo_Resmungao Pq da pr jeito!!é uma "oferta...  positivo

# %%
data = data.sample(1000)
data = data.reset_index()
data = data.drop(columns=['index'])
data['clean_text'] = preprocessing(data['text'])
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data = data.drop(columns=['text'])
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
data.head(15)
# Out:
#                                                  text    target  \
# 0   @Nic0lasSantos devido às circunstâncias eu tiv...  negativo
# 1   @juh_zanetti Ô Juh :( Não sei nem o que dizer ...  negativo
# 2   Se querem uma amiga que vos dê boleias pra Cac...  positivo
# 3   Difícil ser forte quando está vendo sua fraque...  negativo
# 4              época q tudo mundo era amigos ainda :(  negativo
# 5   Yukihira deslumbrado com a beleza de sua amada...  positivo
# 6   gg wp Pain mostrou novamente boas decisões num...  positivo
# 7            Eu só queria abraçar meus dindos cara :(  negativo
# 8   eu sempre vi minha irmã e meu irmão mais velho...  negativo
# 9                         @adrissc_ Suits, de nada :)  positivo
# 10          Feliz por descobrir que tenho 4g ainda :)  positivo
# 11  comi sete pastéis de nata no café da manhã, fo...  positivo
# 12           nbts tour chegando e eu so a tristeza :(  negativo
# 13  @JuMRS28 S tu não tiveres date então o mundo t...  positivo
# 14  mas hoje. a gnt conseguiu se ver e conversar s...  positivo
#
#                                            clean_text
# 0   devido circunstancias tive soltar não lembro d...
# 1                             o cara triste não dizer
# 2   querem amiga de boleia cacaria ultima hora fac...
# 3   difícil forte quando vendo fraqueza chorando f...
# 4       época que tudo mundo amigos ainda cara triste
# 5         cuieira deslumbrado beleza amada cara feliz
# 6   gag wp pain mostrou novamente boas decisões jo...
# 7                queria abracar tios cara cara triste
# 8   sempre vi irma irmão velhos passar ficava estã...
# 9                               bates nada cara feliz
# 10                feliz descobrir kg ainda cara feliz
# 11  comi sete pasteis nata café manha próprio café...
# 12            bits tour chegando tristeza cara triste
# 13  não tiveres date então mundo está louco cego c...
# 14  hoje gente conseguiu ver conversar sozinhas ca...
